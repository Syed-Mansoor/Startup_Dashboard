# %% [markdown]
# #  Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
# %matplotlib inline

# %%
# Loading the Data Set

df = pd.read_csv('startups_cleaned.xls')

# %%
df.head()
# Out:
#          date        startup             vertical  \
# 0  2020-09-01         BYJU’S               E-Tech
# 1  2020-01-13         Shuttl       Transportation
# 2  2020-09-01      Mamaearth           E-commerce
# 3  2020-01-01  Wealth Bucket              FinTech
# 4  2020-01-01         Fashor  Fashion and Apparel
#
#                              subvertical       city  \
# 0                             E-learning  Bengaluru
# 1              App based shuttle service    Gurgaon
# 2  Retailer of baby and toddler products  Bengaluru
# 3                      Online Investment  New Delhi
# 4            Embroiled Clothes For Women     Mumbai
#
#                    investors                 round  Amount in Crores  \
# 0    Tiger Global Management  Private Equity Round          0.013723
# 1  Susquehanna Growth Equity              Series C         66.938493
# 2      Sequoia Capital India              Series B        152.690639
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1406 entries, 0 to 1405
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              1406 non-null   object
#  1   startup           1406 non-null   object
#  2   vertical          1406 non-null   object
#  3   subvertical       1406 non-null   object
#  4   city              1406 non-null   object
#  5   investors         1406 non-null   object
#  6   round             1406 non-null   object
#  7   Amount in Crores  1406 non-null   float64
#  8   month             1406 non-null   object
#  9   year              1406 non-null   int64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 110.0+ KB

# %%
df.describe()
# Out:
#        Amount in Crores         year
# count       1406.000000  1406.000000
# mean         132.327840  2016.931010
# std         1031.550116     0.968658
# min            0.000000  2016.000000
# 25%            2.910950  2016.000000
# 50%            8.317000  2017.000000
# 75%           51.357475  2018.000000
# max        32436.300000  2020.000000

# %%
df.isnull().sum()
# Out:
# date                0
# startup             0
# vertical            0
# subvertical         0
# city                0
# investors           0
# round               0
# Amount in Crores    0
# month               0
# year                0
# dtype: int64

# %% [markdown]
# # Subvertical

# %%
df['subvertical']=df['subvertical'].fillna(0)

# %%
df.isnull().sum()
# Out:
# date                0
# startup             0
# vertical            0
# subvertical         0
# city                0
# investors           0
# round               0
# Amount in Crores    0
# month               0
# year                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1406 entries, 0 to 1405
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              1406 non-null   object
#  1   startup           1406 non-null   object
#  2   vertical          1406 non-null   object
#  3   subvertical       1406 non-null   object
#  4   city              1406 non-null   object
#  5   investors         1406 non-null   object
#  6   round             1406 non-null   object
#  7   Amount in Crores  1406 non-null   float64
#  8   month             1406 non-null   object
#  9   year              1406 non-null   int64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 110.0+ KB

# %% [markdown]
# ## startup

# %%
df['startup'].unique().tolist()
# Out:
# ['BYJU’S',
#  'Shuttl',
#  'Mamaearth',
#  'Wealth Bucket',
#  'Fashor',
#  'Pando',
#  'Zomato',
#  'Ecozen',
#  'CarDekho',
#  'Dhruva Spac',
#  'Rivigo',
#  'Healthians',
#  'Licious',
#  'Trell',
#  'Rein Games',
#  'Lenskart',
#  'Freshworks',
#  'Misters',
#  'Sunstone Eduversity Pvt. Ltd',
#  'Burger Singh',
#  'Ninjacart',
#  'Aye Financ',
#  'SuperGaming',
#  'Clumio',
#  'BikeGo',
#  'Digital Mall Asia',
#  'Medikabazaar',
#  'Vogo Automotiv',
#  'Paytm',
#  'Dunzo',
#  'Udaan',
#  'The Man Company',
#  'FPL Technologies',
#  'Cashflo',
#  'Digital F5',
#  '3rdFli',
#  '75F',
#  'Myelin Foundry',
#  'Atomberg Technology',
#  'GOQii',
#  'Vyapar App',
#  'Progcap',
#  'Alteria Capital',
#  'Pine Labs',
#  'Meesho',
#  'Cars24',
#  'Uniphor',
#  'Zendriv',
#  'Lo! Foods',
#  'Tala',
#  'INDwealth',
#  'HungerBo',
#  'AdmitKard',
#  'Mishry Reviews',
#  'Grofers',
#  'Rapido Bike Taxi',
#  'RenewBuy',
#  'Atlan',
#  'WizCounsel',
#  'Ola Cabs',
#  'Daalchini Technologies',
# ...

# %% [markdown]
# # Vertical

# %%
df['vertical'].unique().tolist()
# Out:
# ['E-Tech',
#  'Transportation',
#  'E-commerce',
#  'FinTech',
#  'Fashion and Apparel',
#  'Logistics',
#  'Hospitality',
#  'Technology',
#  'Aerospace',
#  'B2B-focused foodtech startup',
#  'Video',
#  'Gaming',
#  'Software',
#  'Health and wellness',
#  'Education',
#  'Food and Beverage',
#  'Health and Wellness',
#  'B2B Marketing',
#  'Video Games',
#  'SaaS',
#  'Last Mile Transportation',
#  'Healthcare',
#  'Customer Service',
#  'B2B',
#  'Consumer Goods',
#  'Advertising, Marketing',
#  'IoT',
#  'Information Technology',
#  'Consumer Technology',
#  'Accounting',
#  'Finance',
#  'Customer Service Platform',
#  'Automotive',
#  'EdTech',
#  'Services',
#  'Compliance',
#  'Transport',
#  'Artificial Intelligence',
#  'Tech',
#  'Health Care',
#  'Luxury Label',
#  'Waste Management Service',
#  'Deep-Tech',
#  'Energy',
#  'Digital Media',
#  'Saas',
#  'Automobile',
#  'Agtech',
#  'Social Media',
#  'Fintech',
#  'Edtech',
#  'AI',
#  'Nanotechnology',
# ...

# %%
'Online Home D\\\\xc3\\\\xa9cor'
'Healthcare\\\\nService provider'
'Online Furnishing\\\\neCommerce'
'Digital / Mobile Wallet'
'OnDemand\\\\nMobile Handyman Services'
'Online / Mobile Customer Support'
'Private Jet/ Helicopter Marketplace'
'Chain of Tea Caf\\\\xc3\\\\xa9\\\\xe2\\\\x80\\\\x99s'
'Home Design & D\\\\xc3\\\\xa9cor platform'
'ECommerce Brands\\\\xe2\\\\x80\\\\x99 Full Service Agency'
'Mobile Growth Hacking\\\\nPlatform'
'Home Design & D\\\\xc3\\\\xa9cor solutions'
'Healthcare\\\\nService provider'
'Online Home D\\\\xc3\\\\xa9cor'
# Out:
# 'Online Home D\\\\xc3\\\\xa9cor'

# %%
df['vertical']=df['vertical'].apply(lambda x:str(x).replace('\xa0',''))

# %%
df['vertical']=df['vertical'].apply(lambda x:str(x).replace(' D\\\\xc3\\\\xa9cor',''))
df['vertical']=df['vertical'].apply(lambda x:str(x).replace(' \\xe2\\x80\\x93',''))
df['vertical']=df['vertical'].apply(lambda x:str(x).replace('\\\\n',' '))
df['vertical']=df['vertical'].apply(lambda x:str(x).replace('\\\\xe2\\\\x80\\\\x99',''))
df['vertical']=df['vertical'].apply(lambda x:str(x).replace('\\\\',' '))
df['vertical']=df['vertical'].apply(lambda x:str(x).replace('Chain of Tea Caf\\\\xc3\\\\xa9\\\\xe2\\\\x80\\\\x99s','Chain of Tea Cafes'))

# %%
df['vertical'].unique().tolist()
# Out:
# ['E-Tech',
#  'Transportation',
#  'E-commerce',
#  'FinTech',
#  'Fashion and Apparel',
#  'Logistics',
#  'Hospitality',
#  'Technology',
#  'Aerospace',
#  'B2B-focused foodtech startup',
#  'Video',
#  'Gaming',
#  'Software',
#  'Health and wellness',
#  'Education',
#  'Food and Beverage',
#  'Health and Wellness',
#  'B2B Marketing',
#  'Video Games',
#  'SaaS',
#  'Last Mile Transportation',
#  'Healthcare',
#  'Customer Service',
#  'B2B',
#  'Consumer Goods',
#  'Advertising, Marketing',
#  'IoT',
#  'Information Technology',
#  'Consumer Technology',
#  'Accounting',
#  'Finance',
#  'Customer Service Platform',
#  'Automotive',
#  'EdTech',
#  'Services',
#  'Compliance',
#  'Transport',
#  'Artificial Intelligence',
#  'Tech',
#  'Health Care',
#  'Luxury Label',
#  'Waste Management Service',
#  'Deep-Tech',
#  'Energy',
#  'Digital Media',
#  'Saas',
#  'Automobile',
#  'Agtech',
#  'Social Media',
#  'Fintech',
#  'Edtech',
#  'AI',
#  'Nanotechnology',
# ...

# %%
df.isnull().sum()
# Out:
# date                0
# startup             0
# vertical            0
# subvertical         0
# city                0
# investors           0
# round               0
# Amount in Crores    0
# month               0
# year                0
# dtype: int64

# %% [markdown]
# # subvertical

# %%
df['subvertical']
# Out:
# 0                                              E-learning
# 1                               App based shuttle service
# 2                   Retailer of baby and toddler products
# 3                                       Online Investment
# 4                             Embroiled Clothes For Women
#                               ...
# 1401    Online Fitness & Educational information Aggre...
# 1402                      Indians focused Matchmaking App
# 1403                         Fresh Food Delivery platform
# 1404                          Online marketplace for cars
# 1405                   Mobile & Cloud based App developer
# Name: subvertical, Length: 1406, dtype: object

# %% [markdown]
# # Location

# %%
df['city'].unique().tolist()
# Out:
# ['Bengaluru',
#  'Gurgaon',
#  'New Delhi',
#  'Mumbai',
#  'Chennai',
#  'Pune',
#  'Noida',
#  'Faridabad',
#  'San Francisco',
#  'San Jose,',
#  'Amritsar',
#  'Delhi',
#  'Kormangala',
#  'Hyderabad',
#  'Burnsville',
#  'Menlo Park',
#  'Gurugram',
#  'Palo Alto',
#  'Santa Monica',
#  'Singapore',
#  'Taramani',
#  'Andheri',
#  'Chembur',
#  'Haryana',
#  'New York',
#  'Karnataka',
#  'Mumbai/Bengaluru',
#  'Bhopal',
#  'Bengaluru and Gurugram',
#  'India/Singapore',
#  'Jaipur',
#  'India/US',
#  'Nagpur',
#  'Indore',
#  'New York, Bengaluru',
#  'California',
#  'India',
#  'Rourkela',
#  'Bhubneswar',
#  'Chandigarh',
#  'Delhi & Cambridge',
#  'Kolkata',
#  'Coimbatore',
#  'Bangalore',
#  'Udaipur',
#  'Ahemadabad',
#  'Ahmedabad',
#  'Surat',
#  'Goa',
#  'Gaya',
#  'Vadodara',
#  'Missourie',
#  'Panaji',
#  'Gwalior',
#  'Bangalore/ Bangkok',
#  'Kerala',
#  'Lucknow',
#  'Trivandrum',
#  'SFO / Bangalore',
#  'Pune/Seattle',
#  'Pune / Dubai',
# ...

# %% [markdown]
# # Investors

# %%
df['investors']
# Out:
# 0                                 Tiger Global Management
# 1                               Susquehanna Growth Equity
# 2                                   Sequoia Capital India
# 3                                          Vinod Khatumal
# 4                                 Sprout Venture Partners
#                               ...
# 1401                                       Idein Ventures
# 1402                              TermSheet, ah! Ventures
# 1403    Zodius Technology Fund, Lightspeed Venture Par...
# 1404    Kalaari Capital, Inventus Capital, Tekton Vent...
# 1405                                Info Edge (India) Ltd
# Name: investors, Length: 1406, dtype: object

# %%
sorted(set(df['investors'].str.split(',').str.split('&').sum()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 sorted(set(df['investors'].str.split(',').str.split('&').sum()))
#
# TypeError: 'numpy.float64' object is not iterable

# %%
df[df['investors']=='IDG Ventures India']['startup'].values
# Out:
# array(['Hevo Data'], dtype=object)

# %%
df.iloc[68].investors
# Out:
# 'Blume Ventures'

# %%
sorted(set(df['investors']))
# Out:
# ['1 Capita, Binny Bansal',
#  '1Crowd',
#  '1Crowd (through crowd funding)',
#  '1Crowd, Ankur Capital',
#  '1Crowd, Eureka Forbes Ltd, Shapoorji Pallonji & Co. Ltd.',
#  '3 undisclosed HNIs',
#  '50K Ventures',
#  '91maker.com',
#  'A M Sikander',
#  'A91 Partners',
#  'ABI-Showatech (India) Ltd',
#  'ABM Knowledgeware',
#  'ADAG Reliance Private Equity',
#  'AJ Ventures and Jain International Trade Organisation (JITO)',
#  'ANI Technologies Pvt. Ltd',
#  'APIS Partners',
#  'Aamir Khan',
#  'Aarin Capital',
#  'Aarin Capital, Michael Herzig, Ashish Lakhanpal',
#  'Aavishkaar',
#  'Aavishkaar Venture Management',
#  'Abhinav Bindra, Gaurav Marya',
#  'Abhinav Gupta,',
#  'Abhishek Agarwal, Krishnakumar Nataraj, Sarath Sura, Shanti Mohan, Sarthak and Nihit Agarwal, Suramya Gupta',
#  'Abraaj Group',
#  'Accel (formerly known as Accel Partners)',
#  'Accel Partners',
#  'Accel Partners India',
#  'Accel Partners,',
# ...

# %%
df['investors']=df['investors'].apply(lambda x:str(x).replace('\xa0',' '))
df['investors']=df['investors'].apply(lambda x:str(x).replace('\\\\\\',' '))

# %%
df['investors']=df['investors'].apply(lambda x:str(x).replace('\\\\xe2\\\\x80\\\\x99s',''))
df['investors']=df['investors'].apply(lambda x:str(x).replace('\\\\xe2\\\\x80\\\\x99',''))
df['investors']=df['investors'].apply(lambda x:str(x).replace('\\\\xc2\\\\xa0',''))
df['investors']=df['investors'].apply(lambda x:str(x).replace(', \\\\xc3\\\\x98',''))
df['investors']=df['investors'].apply(lambda x:str(x).replace('\\\\n\\\\n',''))
df['investors']=df['investors'].apply(lambda x:str(x).replace('"Kedaraa Capital, Ontario Teachers\\\\\'"','Kedaraa Capital, Ontario Teachers'))
df['investors']=df['investors'].apply(lambda x:str(x).replace('\\\\xc3\\\\xa9',''))
df['investors']=df['investors'].apply(lambda x:str(x).replace('\\\\xe2\\\\x80\\\\x99O',''))

# %%
df['investors']=df['investors'].apply(lambda x:str(x).replace('and',','))
df['investors']=df['investors'].apply(lambda x:str(x).replace('And',','))
df['investors']=df['investors'].apply(lambda x:str(x).replace('&',','))

# %%
df['investors'].shape
# Out:
# (1406,)

# %%
sorted(set(df['investors'].str.split(',').sum()))
# Out:
# ['',
#  ' ',
#  ' 100 Co-founders Lab ',
#  ' 122 West Ventures',
#  ' 14 others',
#  ' 1Crowd',
#  ' 3ONE4 Capital Advisors',
#  ' 3one4 Capital',
#  ' 3one4 Capital Advisors LLP',
#  ' 500 Startups',
#  ' 91SpringBoard',
#  ' ABB Technology Ventures',
#  ' ABCOM Investments',
#  ' AET Fund',
#  ' AL Nour International Holdings ',
#  ' Aarin Capital',
#  ' Abhai S. Rao',
#  ' Abhay Singhal',
#  ' Abhishek Acharya',
#  ' Abhishek Goyal',
#  ' Abhishek Jain',
#  ' Abstract Ventures',
#  ' Abu Farhan Azmi',
#  ' Accel',
#  ' Accel India',
#  ' Accel Partner',
#  ' Accel Partners',
#  ' Accel Partners ',
#  ' Accel Partners RNT Associates',
#  ' Accion Venture Labs',
#  ' Acumen Fund',
#  ' Adi Saravanan',
#  ' Aditya Agarwal',
#  ' Aditya Malik ',
#  ' Aditya Verma',
#  ' Aditya Vij',
#  ' AdvantEdge Partners',
#  ' Adveq Management',
#  ' Ajay Bhatia',
#  ' Ajay Modani',
#  ' Akash Garg',
#  ' Akatsuki ',
#  ' Alfa Capital',
#  ' Alok Mittal ',
# ...

# %%
df
# Out:
#             date        startup             vertical  \
# 0     2020-09-01         BYJU’S               E-Tech
# 1     2020-01-13         Shuttl       Transportation
# 2     2020-09-01      Mamaearth           E-commerce
# 3     2020-01-01  Wealth Bucket              FinTech
# 4     2020-01-01         Fashor  Fashion and Apparel
# ...          ...            ...                  ...
# 1401  2016-09-01          Qriyo    Consumer Internet
# 1402  2016-09-01           Aisl    Consumer Internet
# 1403  2016-09-01      FreshMenu    Consumer Internet
# 1404  2016-09-01        Truebil           E-commerce
# 1405  2016-09-01     Rare Media           Technology
#
#                                             subvertical       city  \
# 0                                            E-learning  Bengaluru
# 1                             App based shuttle service    Gurgaon
# 2                 Retailer of baby and toddler products  Bengaluru
# ...

# %% [markdown]
# # round

# %%
df['round'].unique().tolist()
# Out:
# ['Private Equity Round',
#  'Series C',
#  'Series B',
#  'Pre-series A',
#  'Seed Round',
#  'Series A',
#  'Series D',
#  'Seed',
#  'Series F',
#  'Series E',
#  'Series G',
#  'Series H',
#  'Venture',
#  'Debt Funding',
#  'Seed Funding',
#  'Funding Round',
#  'Corporate Round',
#  'Maiden Round',
#  'pre-series A',
#  'Single Venture',
#  'Venture Round',
#  'Pre-Series A',
#  'Angel',
#  'Series J',
#  'Angel Round',
#  'pre-Series A',
#  'Venture - Series Unknown',
#  'Bridge Round',
#  'Private Equity',
#  'Debt and Preference capital',
#  'Inhouse Funding',
#  'Seed/ Angel Funding',
#  'Debt',
#  'Pre Series A',
#  'Equity',
#  'Debt-Funding',
#  'Mezzanine',
#  'Series B (Extension)',
#  'Equity Based Funding',
#  'Private Funding',
#  'Seed / Angel Funding',
#  'Seed/Angel Funding',
#  'Seed / Angle Funding',
#  'Private',
#  'Angel / Seed Funding',
#  'Structured Debt',
#  'Term Loan',
#  'PrivateEquity']

# %%
df['round']=df['round'].apply(lambda x:str(x).replace('Series C','Series'))
df['round']=df['round'].apply(lambda x:str(x).replace('Series B','Series'))
df['round']=df['round'].apply(lambda x:str(x).replace('Series F','Series'))
df['round']=df['round'].apply(lambda x:str(x).replace('Series G','Series'))
df['round']=df['round'].apply(lambda x:str(x).replace('Series H','Series'))

# %%
df['round']
# Out:
# 0       Private Equity Round
# 1                     Series
# 2                     Series
# 3               Pre-series A
# 4                 Seed Round
#                 ...
# 1401            Seed Funding
# 1402            Seed Funding
# 1403          Private Equity
# 1404          Private Equity
# 1405          Private Equity
# Name: round, Length: 1406, dtype: object

# %%
df
# Out:
#             date        startup             vertical  \
# 0     2020-09-01         BYJU’S               E-Tech
# 1     2020-01-13         Shuttl       Transportation
# 2     2020-09-01      Mamaearth           E-commerce
# 3     2020-01-01  Wealth Bucket              FinTech
# 4     2020-01-01         Fashor  Fashion and Apparel
# ...          ...            ...                  ...
# 1401  2016-09-01          Qriyo    Consumer Internet
# 1402  2016-09-01           Aisl    Consumer Internet
# 1403  2016-09-01      FreshMenu    Consumer Internet
# 1404  2016-09-01        Truebil           E-commerce
# 1405  2016-09-01     Rare Media           Technology
#
#                                             subvertical       city  \
# 0                                            E-learning  Bengaluru
# 1                             App based shuttle service    Gurgaon
# 2                 Retailer of baby and toddler products  Bengaluru
# ...

# %%
print(df[df['investors'].str.contains("Sequoia Capital")]['startup'].nunique())
# Out:
# 41

# %%
df[df['investors']=='Sequoia Capital India']['startup'].values
# Out:
# array(['Mamaearth', 'Blackbuck', 'Belong'], dtype=object)

# %%
df[df['investors'].str.contains("Sequoia Capital India")]['startup'].unique()
# Out:
# array(['Mamaearth', 'Mogli', 'Blackbuck', 'Samosa Labs', 'Metro Bikes',
#        'Meesho', 'OncoStem', 'OYO Rooms', 'Unacademy', 'Dhruva', 'Faasos',
#        'Oyo Rooms', 'Belong', 'Pocket Aces', 'FreshDesk', 'DailyHunt',
#        'HealthKart'], dtype=object)

# %% [markdown]
# #  startup

# %%
df[df['startup']=="Rapido Bike Taxi"]
# Out:
#           date           startup        vertical subvertical       city  \
# 57  2019-07-08  Rapido Bike Taxi  Transportation   Bike Taxi  Bengaluru
#
#              investors   round  Amount in Crores month  year
# 57  Westbridge Capital  Series           32436.3  July  2019

# %%
df[df['startup']=="Rapido"]
# Out:
#            date startup           vertical  \
# 419  2017-01-11  Rapido         Technology
# 507  2017-05-09  Rapido  Consumer Internet
#
#                                subvertical       city  \
# 419  Bike and Taxi pooling online platform  Hyderabad
# 507             Bike Aggregator Mobile App  Bangalore
#
#                              investors               round  Amount in Crores  \
# 419     Skycatcher Fund, Aravind Sanka  Seed/Angel Funding          2.738206
# 507  Battery Road Digital Holdings LLC        Seed Funding          3.509774
#
#        month  year
# 419  January  2017
# 507      May  2017

# %%
df['startup']=df['startup'].apply(lambda x: x.lower())

# %%
df['startup']=df['startup'].apply(lambda x:str(x).replace('Rapido Bike Taxi Bike Taxi','Rapido Bike Taxi'))

# %%
df.loc[df['startup']=="Rapido", 'vertical'] = df[df['startup']=="Rapido"]['vertical'].apply(lambda x: str(x).replace('Technology','Transportation'))

# %%
df['startup']=df['startup'].apply(lambda x:str(x).replace('ola cabs','ola'))
df['startup']=df['startup'].apply(lambda x:str(x).replace('ola electric','ola'))
df['startup']=df['startup'].apply(lambda x:str(x).replace('ola','ola'))
df['startup']=df['startup'].apply(lambda x:str(x).replace('flipkart.com','flipkart'))
df['startup']=df['startup'].apply(lambda x:str(x).replace('paytm marketplace','paytm'))

# %%
df['startup'].nunique()
# Out:
# 1157

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1406 entries, 0 to 1405
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              1406 non-null   object
#  1   startup           1406 non-null   object
#  2   vertical          1406 non-null   object
#  3   subvertical       1406 non-null   object
#  4   city              1406 non-null   object
#  5   investors         1406 non-null   object
#  6   round             1406 non-null   object
#  7   Amount in Crores  1406 non-null   float64
#  8   month             1406 non-null   object
#  9   year              1406 non-null   int64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 110.0+ KB

# %%
df
# Out:
#             date        startup             vertical  \
# 0     2020-09-01         byju’s               E-Tech
# 1     2020-01-13         shuttl       Transportation
# 2     2020-09-01      mamaearth           E-commerce
# 3     2020-01-01  wealth bucket              FinTech
# 4     2020-01-01         fashor  Fashion and Apparel
# ...          ...            ...                  ...
# 1401  2016-09-01          qriyo    Consumer Internet
# 1402  2016-09-01           aisl    Consumer Internet
# 1403  2016-09-01      freshmenu    Consumer Internet
# 1404  2016-09-01        truebil           E-commerce
# 1405  2016-09-01     rare media           Technology
#
#                                             subvertical       city  \
# 0                                            E-learning  Bengaluru
# 1                             App based shuttle service    Gurgaon
# 2                 Retailer of baby and toddler products  Bengaluru
# ...

# %% [markdown]
# # Amount

# %%
df['amount']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'amount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df['amount']
#
# ...

# %%
df['amount'].unique()
# Out:
# array([1.65000000e+03, 6.63992505e+01, 1.51460595e+02, 2.47500000e+01,
#        1.48500000e+01, 7.42500000e+01, 1.23750000e+03, 4.95000000e+01,
#        5.77500000e+02, 4.12500000e+02, 1.65000000e+02, 9.90000000e+01,
#        2.47500000e+02, 1.65000000e+01, 1.90575000e+03, 4.00950000e+00,
#        1.23750000e+01, 0.00000000e+00, 2.14500000e+02, 1.43642936e+02,
#        1.07250000e+01, 1.11375000e+03, 2.47500000e+00, 1.81500000e+03,
#        1.30350000e+02, 2.33475000e+03, 8.25000000e+03, 3.71250000e+02,
#        4.82625000e+03, 3.71250000e+01, 2.72250000e+01, 4.12500000e+01,
#        1.48500000e+02, 8.25000000e+00, 8.25000000e+01, 3.71250000e+03,
#        1.15500000e+03, 3.14160000e+02, 1.03125000e+03, 9.07500000e+01,
#        4.20750000e+02, 3.05250000e+02, 4.12500000e+00, 9.07500000e+02,
#        1.23750000e+02, 5.43675000e+01, 3.21750000e+04, 1.56750000e+02,
#        2.06250000e+01, 1.19625000e+00, 4.95000000e+02, 1.32000000e+02,
# ...

# %%
df['amount']=df['amount'].apply(lambda x:str(x).replace('e-',''))
df['amount']=df['amount'].apply(lambda x:str(x).replace('e+',''))

# %%
df
# Out:
#             date        startup             vertical  \
# 0     2020-09-01         byju’s               E-Tech
# 1     2020-01-13         shuttl       Transportation
# 2     2020-09-01      mamaearth           E-commerce
# 3     2020-01-01  wealth bucket              FinTech
# 4     2020-01-01         fashor  Fashion and Apparel
# ...          ...            ...                  ...
# 1401  2016-09-01          qriyo    Consumer Internet
# 1402  2016-09-01           aisl    Consumer Internet
# 1403  2016-09-01      freshmenu    Consumer Internet
# 1404  2016-09-01        truebil           E-commerce
# 1405  2016-09-01     rare media           Technology
#
#                                             subvertical       city  \
# 0                                            E-learning  Bengaluru
# 1                             App based shuttle service    Gurgaon
# 2                 Retailer of baby and toddler products  Bengaluru
# ...

# %%
df.to_csv('startup_data',index=False)

# %% [markdown]
# # City

# %%
df['city'].unique().tolist()
# Out:
# ['Bengaluru',
#  'Gurgaon',
#  'New Delhi',
#  'Mumbai',
#  'Chennai',
#  'Pune',
#  'Noida',
#  'Faridabad',
#  'San Francisco',
#  'San Jose,',
#  'Amritsar',
#  'Delhi',
#  'Kormangala',
#  'Hyderabad',
#  'Burnsville',
#  'Menlo Park',
#  'Gurugram',
#  'Palo Alto',
#  'Santa Monica',
#  'Singapore',
#  'Taramani',
#  'Andheri',
#  'Chembur',
#  'Haryana',
#  'New York',
#  'Karnataka',
#  'Mumbai/Bengaluru',
#  'Bhopal',
#  'Bengaluru and Gurugram',
#  'India/Singapore',
#  'Jaipur',
#  'India/US',
#  'Nagpur',
#  'Indore',
#  'New York, Bengaluru',
#  'California',
#  'India',
#  'Rourkela',
#  'Bhubneswar',
#  'Chandigarh',
#  'Delhi & Cambridge',
#  'Kolkata',
#  'Coimbatore',
#  'Bangalore',
#  'Udaipur',
#  'Ahemadabad',
#  'Ahmedabad',
#  'Surat',
#  'Goa',
#  'Gaya',
#  'Vadodara',
#  'Missourie',
#  'Panaji',
#  'Gwalior',
#  'Bangalore/ Bangkok',
#  'Kerala',
#  'Lucknow',
#  'Trivandrum',
#  'SFO / Bangalore',
#  'Pune/Seattle',
#  'Pune / Dubai',
# ...

# %%
df['city']=df['city'].apply(lambda x:str(x).replace('Nw Delhi','New Delhi'))

# %%
df['city'].unique().tolist()
# Out:
# ['Bengaluru',
#  'Gurgaon',
#  'New Delhi',
#  'Mumbai',
#  'Chennai',
#  'Pune',
#  'Noida',
#  'Faridabad',
#  'San Francisco',
#  'San Jose,',
#  'Amritsar',
#  'Delhi',
#  'Kormangala',
#  'Hyderabad',
#  'Burnsville',
#  'Menlo Park',
#  'Gurugram',
#  'Palo Alto',
#  'Santa Monica',
#  'Singapore',
#  'Taramani',
#  'Andheri',
#  'Chembur',
#  'Haryana',
#  'New York',
#  'Karnataka',
#  'Mumbai/Bengaluru',
#  'Bhopal',
#  'Bengaluru and Gurugram',
#  'India/Singapore',
#  'Jaipur',
#  'India/US',
#  'Nagpur',
#  'Indore',
#  'New York, Bengaluru',
#  'California',
#  'India',
#  'Rourkela',
#  'Bhubneswar',
#  'Chandigarh',
#  'Delhi & Cambridge',
#  'Kolkata',
#  'Coimbatore',
#  'Bangalore',
#  'Udaipur',
#  'Ahemadabad',
#  'Ahmedabad',
#  'Surat',
#  'Goa',
#  'Gaya',
#  'Vadodara',
#  'Missourie',
#  'Panaji',
#  'Gwalior',
#  'Bangalore/ Bangkok',
#  'Kerala',
#  'Lucknow',
#  'Trivandrum',
#  'SFO / Bangalore',
#  'Pune/Seattle',
#  'Pune / Dubai',
# ...

# %%
df['city'].unique()
# Out:
# array(['Bengaluru', 'Gurgaon', 'New Delhi', 'Mumbai', 'Chennai', 'Pune',
#        'Noida', 'Faridabad', 'San Francisco', 'San Jose,', 'Amritsar',
#        'Delhi', 'Kormangala', 'Hyderabad', 'Burnsville', 'Menlo Park',
#        'Gurugram', 'Palo Alto', 'Santa Monica', 'Singapore', 'Taramani',
#        'Andheri', 'Chembur', 'Haryana', 'New York', 'Karnataka',
#        'Mumbai/Bengaluru', 'Bhopal', 'Bengaluru and Gurugram',
#        'India/Singapore', 'Jaipur', 'India/US', 'Nagpur', 'Indore',
#        'New York, Bengaluru', 'California', 'India', 'Rourkela',
#        'Bhubneswar', 'Chandigarh', 'Delhi & Cambridge', 'Kolkata',
#        'Coimbatore', 'Bangalore', 'Udaipur', 'Ahemadabad', 'Ahmedabad',
#        'Surat', 'Goa', 'Gaya', 'Vadodara', 'Missourie', 'Panaji',
#        'Gwalior', 'Bangalore/ Bangkok', 'Kerala', 'Lucknow', 'Trivandrum',
#        'SFO / Bangalore', 'Pune/Seattle', 'Pune / Dubai',
#        'Bangalore / SFO', 'Varanasi', 'New Delhi / US', 'Mumbai / UK',
# ...

# %%
df.columns
# Out:
# Index(['date', 'startup', 'vertical', 'subvertical', 'city', 'investors',
#        'round', 'Amount in Crores', 'month', 'year'],
#       dtype='object')

# %%
 df[df['startup'].str.contains(startup)].groupby('investors').sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 df[df['startup'].str.contains(startup)].groupby('investors').sum()
#
# NameError: name 'startup' is not defined

# %%
df[df['startup'].str.contains("mamaearth")].groupby('investors').sum(numeric_only=True)
# Out:
#                              Amount in Crores  year
# investors
# Sequoia Capital India              152.690639  2020
# Stellaris Ventures , Others         33.268000  2018
